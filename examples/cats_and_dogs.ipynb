# %% [markdown]
# # Visual Transformer with Linformer
#
# Training Visual Transformer on *Dogs vs Cats Data*
#
# * Dogs vs. Cats Redux: Kernels Edition - https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition
# * Base Code - https://www.kaggle.com/reukki/pytorch-cnn-tutorial-with-cats-and-dogs/
# * Efficient Attention Implementation - https://github.com/lucidrains/vit-pytorch#efficient-attention

# %%
# !pip -q install vit_pytorch linformer

# %% [markdown]
# ## Import Libraries

# %%
from __future__ import print_function

import glob
from itertools import chain
import os
import random
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from linformer import Linformer
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm

#我感觉这里用的是简化版Transformer
from vit_pytorch.efficient import ViT

# %%
print(f"Torch: {torch.__version__}")
# Out:
# Torch: 1.13.1+cu116

# %%
# Training settings
batch_size = 64

#用CNN时需要将b调小，不然内存不够用
# batch_size = 2


epochs = 20
lr = 3e-5
gamma = 0.7
seed = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(seed)

# %%
device = 'cuda'

# %% [markdown]
# ## Load Data

# %%
# os.makedirs('data', exist_ok=True)

# %%
train_dir = '../data/train'
test_dir = '../data/test'

# %%
# with zipfile.ZipFile('train.zip') as train_zip:
#     train_zip.extractall('data')
    
# with zipfile.ZipFile('test.zip') as test_zip:
#     test_zip.extractall('data')

# %%
train_list = glob.glob(os.path.join(train_dir,'*.jpg'))
test_list = glob.glob(os.path.join(test_dir, '*.jpg'))

# %%
print(f"Train Data: {len(train_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 25000
# Test Data: 12500

# %%
# labels = [path.split('/')[-1].split('.')[0] for path in train_list]
#源代码是linux环境，要改成windows环境路径，把路径中的标签取出来
labels = [path.split('/')[-1].split('\\')[-1].split('.')[0] for path in train_list]
labels
# Out:
# ['dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  'cat',
#  'cat',
#  'dog',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'dog',
#  'cat',
#  'cat',
#  ...]

# %% [markdown]
# ## Random Plots

# %%
#随机展示数据集中的一些图片
random_idx = np.random.randint(1, len(train_list), size=9)
fig, axes = plt.subplots(3, 3, figsize=(16, 12))

for idx, ax in enumerate(axes.ravel()):
    img = Image.open(train_list[idx])
    ax.set_title(labels[idx])
    ax.imshow(img)

# %% [markdown]
# ## Split

# %%
train_list, valid_list = train_test_split(train_list, 
                                          test_size=0.2,
                                          stratify=labels,
                                          random_state=seed)

# %%
print(f"Train Data: {len(train_list)}")
print(f"Validation Data: {len(valid_list)}")
print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 16000
# Validation Data: 4000
# Test Data: 12500

# %% [markdown]
# ## Image Augmentation

# %%
train_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)


test_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)

# %% [markdown]
# ## Load Datasets

# %%
class CatsDogsDataset(Dataset):
    def __init__(self, file_list, transform=None):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        self.filelength = len(self.file_list)
        return self.filelength

    def __getitem__(self, idx):
        img_path = self.file_list[idx]
        img = Image.open(img_path)
        img_transformed = self.transform(img)

        label = img_path.split('/')[-1].split('\\')[-1].split('.')[0]
        label = 1 if label == "dog" else 0

        return img_transformed, label

# %%
train_data = CatsDogsDataset(train_list, transform=train_transforms)
valid_data = CatsDogsDataset(valid_list, transform=test_transforms)
test_data = CatsDogsDataset(test_list, transform=test_transforms)

# %%
train_loader = DataLoader(dataset = train_data, batch_size=batch_size, shuffle=True )
valid_loader = DataLoader(dataset = valid_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset = test_data, batch_size=batch_size, shuffle=True)

# %%
print(len(train_data), len(train_loader))
# Out:
# 16000 250

# %%
print(len(valid_data), len(valid_loader))
# Out:
# 4000 63

# %% [markdown]
# ## Efficient Attention

# %% [markdown]
# ### Linformer

# %%
efficient_transformer = Linformer(
    dim=128,
    seq_len=49+1,  # 7x7 patches + 1 cls-token
    depth=12,
    heads=8,
    k=64
)

# %% [markdown]
# ### Visual Transformer

# %%
#感觉这个是简化版的超参数
model = ViT(
    dim=128,
    image_size=224,
    patch_size=32,
    num_classes=2,
    transformer=efficient_transformer,
    channels=3,
).to(device)

#这个是论文中的ViT base超参数
# model = ViT(
#     image_size=224,
#     patch_size=32,
#     num_classes=2,
#     dim=768,
#     depth = 12,
#     heads=12,
#     mlp_dim=3072,
#     dropout=0.1,
#     emb_dropout=0.1
# ).to(device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12444\883581167.py in <module>
#       7     transformer=efficient_transformer,
#       8     channels=3,
# ----> 9     weights=True
#      10 ).to(device)
#      11
#
# TypeError: __init__() got an unexpected keyword argument 'weights'

# %%
#resnet50深度学习框架找不到适合的cuDNN算法，导致无法进行卷积计算，故用resnet18
import torchvision
model =torchvision.models.resnet18(weights=True).to(device)
model.fc=nn.Sequential(
    nn.Linear(512,2)
).to(device)
# Out:
# D:\app\anaconda\envs\VGG\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### Training

# %%
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)
# scheduler
scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

# %%
for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# Epoch : 1 - loss : 0.1676 - acc: 0.9263 - val_loss : 0.0647 - val_acc: 0.9754
#   0%|          | 0/250 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12444\899787573.py in <module>
#       3     epoch_accuracy = 0
#       4
# ----> 5     for data, label in tqdm(train_loader):
#       6         data = data.to(device)
#       7         label = label.to(device)
#
# D:\app\anaconda\envs\VGG\lib\site-packages\tqdm\notebook.py in __iter__(self)
#     252         try:
#     253             it = super(tqdm_notebook, self).__iter__()
# --> 254             for obj in it:
#     255                 # return super(tqdm...) will not catch exception
#     256                 yield obj
#
# D:\app\anaconda\envs\VGG\lib\site-packages\tqdm\std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# ~\AppData\Local\Temp\ipykernel_12444\3789578630.py in __getitem__(self, idx)
#      11         img_path = self.file_list[idx]
#      12         img = Image.open(img_path)
# ---> 13         img_transformed = self.transform(img)
#      14
#      15         label = img_path.split('/')[-1].split('\\')[-1].split('.')[0]
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torchvision\transforms\transforms.py in forward(self, img)
#     344             PIL Image or Tensor: Rescaled image.
#     345         """
# --> 346         return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#     347
#     348     def __repr__(self) -> str:
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torchvision\transforms\functional.py in resize(img, size, interpolation, max_size, antialias)
#     472             warnings.warn("Anti-alias option is always applied for PIL Image input. Argument antialias is ignored.")
#     473         pil_interpolation = pil_modes_mapping[interpolation]
# --> 474         return F_pil.resize(img, size=output_size, interpolation=pil_interpolation)
#     475
#     476     return F_t.resize(img, size=output_size, interpolation=interpolation.value, antialias=antialias)
#
# D:\app\anaconda\envs\VGG\lib\site-packages\torchvision\transforms\functional_pil.py in resize(img, size, interpolation)
#     250         raise TypeError(f"Got inappropriate size arg: {size}")
#     251
# --> 252     return img.resize(tuple(size[::-1]), interpolation)
#     253
#     254
#
# D:\app\anaconda\envs\VGG\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1987             return im.convert(self.mode)
#    1988
# -> 1989         self.load()
#    1990
#    1991         if reducing_gap is not None and resample != NEAREST:
#
# D:\app\anaconda\envs\VGG\lib\site-packages\PIL\ImageFile.py in load(self)
#     253
#     254                             b = b + s
# --> 255                             n, err_code = decoder.decode(b)
#     256                             if n < 0:
#     257                                 break
#
# KeyboardInterrupt:
